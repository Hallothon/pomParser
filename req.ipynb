# %%
import requests
from pomParser import pomParser
import time
obj=pomParser()
print(obj.clash)
data=obj.dependencies['dependency']
print(data)
# Out:
# 0
# [{'groupId': 'org.junit.jupiter', 'artifactId': 'junit-jupiter-engine', 'version': '5.9.1'}]

# %%
all_new_data=[]    #contains latest version of aall dependencies
def findversions(data):
    group=data["groupId"]
    arti=data["artifactId"]
    url="https://search.maven.org/solrsearch/select?q=g:{}+AND+a:{}&core=gav&rows=20&wt=json".format(group,arti)

    # g:com.google.inject
    # guice
    response=requests.get(url)

    jsondata=response.json()
    # 
    #print(jsondata)
    newvers=[]
    # newvers=[jsondata['response']['docs'][0]['v'],jsondata['response']['docs'][1]['v']]
    for i in range(19):
        d={}
        d["groupId"]=jsondata['response']['docs'][i]['g']
        d["artifactId"]=jsondata['response']['docs'][i]['a']
        d["version"]=jsondata['response']['docs'][i]['v']
        newvers.append(d)
    print(newvers[0])
    if(newvers[0]['version']>data['version']):
        print(data['artifactId'],newvers[0]['version'],"is the latest version ","not ",data['version'])
    
    all_new_data.append(newvers[0])
    # all_new_data.add(newvers[0])

# %%
for i in range(len(data)):
    findversions(data[i])
print(all_new_data)
# Out:
# {'groupId': 'org.junit.jupiter', 'artifactId': 'junit-jupiter-engine', 'version': '5.9.1'}
# [{'groupId': 'org.junit.jupiter', 'artifactId': 'junit-jupiter-engine', 'version': '5.9.1'}]

# %%
# from selenium import webdriver
# def find_dep(gid,aid,v):
#     driver = webdriver.Edge()
#     all_dependencies=[]
#     t=[]
#     tempk=[]
#     print('https://mvnrepository.com/artifact/{}/{}/{}'.format(gid,aid,v))
#     try:
#         driver.get('https://mvnrepository.com/artifact/{}/{}/{}'.format(gid,aid,v))
        
#     except:
#         return
#     try:

#         elements = driver.find_element("xpath","/html/body/div/main/div[1]/div[5]/div/table")
#         k=elements.text.split("\n")
#         print("elements:",elements.text)
#         for i in k:
#             if "org." in i:
#                 tempk.append(i)
#         for i in tempk:
#             t.append(i.split(" "))
#         for i in tempk:
#             json_all_dep['groupId']=i[0].strip()
#             json_all_dep['artifactId']=i[2].strip()
#             json_all_dep['version']=i[3].strip()
#             json_all_dep['newversion']=i[-1].strip()
#             all_dependencies.append(json_all_dep)
        
#     except:
#         elements = driver.find_element("xpath","/html/body/div/main/div[1]/div[4]/div/table")
#         print("elements:",elements.text)
#         k=elements.text.split("\n")
#         for i in k:
#             if "org." in i:
#                 tempk.append(i)
#         for i in tempk:
#             t.append(i.split(" "))
#         for i in tempk:
#             json_all_dep['groupId']=i[0].strip()
#             json_all_dep['artifactId']=i[2].strip()
#             json_all_dep['version']=i[3].strip()
#             json_all_dep['newversion']=i[-1].strip()
#             all_dependencies.append(json_all_dep)
#         # k=elements.text.split("Apache 2.0\norg.seleniumhq.selenium »")
#         if(k):
#             for i in range(1,len(k)):
#                 json_all_dep={}
#                 allfile=k[i].split(" ")
#                 json_all_dep['dependecy']=allfile[1]
#                 json_all_dep['oldversion']=allfile[2]
#                 json_all_dep['newversion']=allfile[3]
#                 all_dependencies.append(json_all_dep)
    
    
    
#     #print(elements.text)
#     #print(">>>>>>>>>>>>>>>>>>>>>>>>>")

    
#     #print("temp:",k)
    
    
#     # print("tempk::",tempk)
    
#     # print("t   ==",t)
    
#     print(all_dependencies)
#     return (all_dependencies)



#     # for i in range(1,len(k)):
#     #     json_all_dep={}
#     #     allfile=k[i].split(" ")
#     #     gid=k[0]
#     #     print(gid)
        
#     #     json_all_dep['artifactId']=allfile[1]
#     #     json_all_dep['version']=allfile[2]
#     #     json_all_dep['newversion']=allfile[3]
#     #     json_all_dep['groupId']=gid
        
#     # print(all_dependencies)
#     # return (all_dependencies)

    
#     # m=k[1].split(' ')
#     # json_all_dep={}
#     # json_all_dep['dependency']=m[0]
#     # json_all_dep['oldversion']=m[0]
#     # json_all_dep['newversion']=m[0]

#     # for i  in range(len(elements)):
#     #     json_all_dep={}
#     #     depend=driver.find_element("xpath","/html/body/div/main/div[1]/div[5]/div/table/tbody/tr[{}]/td[3]/a[2]".format(i))
#     #     oldversion=driver.find_element("xpath","/html/body/div/main/div[1]/div[5]/div/table/tbody/tr[{}]/td[4]/a".format(i))
#     #     newversion=driver.find_element("xpath","/html/body/div/main/div[1]/div[5]/div/table/tbody/tr[{}]/td[5]/a[2]".format(i))
#     #     json_all_dep['depend']=depend.text
#     #     json_all_dep['old_version']=oldversion.text
    
#     #     json_all_dep['new_version']=newversion.text
#     #     all_dependencies.append(json_all_dep) 1

# # elem = driver.find_elements_by_class_name('grid')  # Find the search box
# # print(elem)
# i=0

# while(i<len(all_new_data)):
#     try:
#         print(all_new_data[i]['groupId'],all_new_data[i]['artifactId'],all_new_data[i]['version'])
#         a=find_dep(all_new_data[i]['groupId'],all_new_data[i]['artifactId'],all_new_data[i]['version'])
#         for j in a:
#             if(j not in all_new_data):
#                 all_new_data.append(j)
#         i+=1
#     except:
#         break
    
# print(all_new_data)

# # temp=[]

# # for i in all_new_data:
# #     print(i["groupId"],i["artifactId"],i["version"])
# #     a=find_dep(i["groupId"],i["artifactId"],i["version"])
# #     if(a):

# #         for j in a:
# #             temp.append(j)
# # print(temp)

# %%
from selenium import webdriver
depObj={}
conflicts={}


driver = webdriver.Edge()
def find_dep(gid,aid,v):
    time.sleep(2)
    print('https://mvnrepository.com/artifact/{}/{}/{}'.format(gid,aid,v))
    # driver = webdriver.Edge()
    print(driver.get('https://mvnrepository.com/artifact/{}/{}/{}'.format(gid,aid,v)))
    try:
        elements = driver.find_element("xpath","/html/body/div/main/div[1]/div[5]/div/table")
    except:
        elements = driver.find_element("xpath","/html/body/div/main/div[1]/div[4]/div/table")
        
    all_dependencies=[]
    
    print(elements.text)
    k=elements.text.split("\n")
    temp=[]
    
    for i in k:
        if "»" in i:
            temp.append(i.strip())

    print(temp)
    if temp==[]:
        return []
    else:
         for j in temp:
            display_json={}
            a=j.split(" ")  
            a=a[:1]+a[2:]
            display_json["groupId"]=a[0]
            display_json["version"]=a[2]
            display_json["artifactId"]=a[1]
            display_json["newVersion"]=a[3]
            all_dependencies.append(display_json)
            if a[1] in depObj.keys() and a[2]!=depObj[a[1]]['version']:
                        if a[2] in conflicts.keys():
                            conflicts[a[1]].append(a[2])
                        else:
                            conflicts[a[1]]=[a[2]]
            else:
                depObj[a[1]]=display_json
         return(all_dependencies)




    
    # if(k):
    #     for i in range(1,len(k)):
    #         json_all_dep={}
    #         allfile=k[i].split(" ")
    #         json_all_dep['dependecy']=allfile[1]
    #         json_all_dep['oldversion']=allfile[2]
    #         json_all_dep['newversion']=allfile[3]
    #         all_dependencies.append(json_all_dep)
    # print(all_dependencies)
i=0
n=len(all_new_data)
while(i<n):
    print(len(all_new_data))
    try:
        print(all_new_data[i]['groupId'],all_new_data[i]['artifactId'],all_new_data[i]['version'])
        a=find_dep(all_new_data[i]['groupId'],all_new_data[i]['artifactId'],all_new_data[i]['version'])
        for j in a:
            if(j not in all_new_data):
                all_new_data.append(j)
        n=len(all_new_data)
        i+=1
    except Exception as err:
        print(err)
        break
    
print(all_new_data)
print(conflicts)
# Out:
# 4
# org.junit.jupiter junit-jupiter-engine 5.9.1
# https://mvnrepository.com/artifact/org.junit.jupiter/junit-jupiter-engine/5.9.1
# None
# Category/License Group / Artifact Version Updates
# Annotation Lib
# Apache 2.0
# org.apiguardian » apiguardian-api 1.1.2 ✔
# Testing
# EPL 2.0
# org.junit.jupiter » junit-jupiter-api 5.9.1 ✔
#
# EPL 2.0
# org.junit.platform » junit-platform-engine 1.9.1 ✔
# ['org.apiguardian » apiguardian-api 1.1.2 ✔', 'org.junit.jupiter » junit-jupiter-api 5.9.1 ✔', 'org.junit.platform » junit-platform-engine 1.9.1 ✔']
# 4
# org.apiguardian apiguardian-api 1.1.2
# https://mvnrepository.com/artifact/org.apiguardian/apiguardian-api/1.1.2
# None
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div/main/div[1]/div[4]/div/table"}
#   (Session info: MicrosoftEdge=107.0.1418.35)
# Stacktrace:
# Backtrace:
# 	Microsoft::Applications::Events::EventProperties::unpack [0x0033E7C3+19811]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x00230E91+890481]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x0008DAAE+4190]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x000B87DF+99727]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x000B8981+100145]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x000DF792+259394]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x000CD514+185028]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x000B11DB+69515]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x000DE051+253441]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x000CD246+184310]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x000B0594+66372]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x000AFE3C+64492]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x000B0BEF+67999]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x00557965+703973]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x004CADAB+127531]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x004CA662+125666]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x004CE87B+142587]
# 	Microsoft::Applications::Events::ILogManager::DispatchEventBroadcast [0x004CB6E3+129891]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x002438FD+966877]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x0024E728+1011464]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x0024E84D+1011757]
# 	Microsoft::Applications::Events::ISemanticContext::SetTicket [0x002602D4+1084084]
# 	BaseThreadInitThunk [0x769E6739+25]
# 	RtlGetFullPathName_UEx [0x773F8FD2+1218]
# 	RtlGetFullPathName_UEx [0x773F8F9D+1165]
# 	(No symbol) [0x00000000]
#
# [{'groupId': 'org.junit.jupiter', 'artifactId': 'junit-jupiter-engine', 'version': '5.9.1'}, {'groupId': 'org.apiguardian', 'version': '1.1.2', 'artifactId': 'apiguardian-api', 'newVersion': '✔'}, {'groupId': 'org.junit.jupiter', 'version': '5.9.1', 'artifactId': 'junit-jupiter-api', 'newVersion': '✔'}, {'groupId': 'org.junit.platform', 'version': '1.9.1', 'artifactId': 'junit-platform-engine', 'newVersion': '✔'}]
# {}
